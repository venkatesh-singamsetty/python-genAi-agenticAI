# %% [markdown]
# ## WITHOUT USING MATLIBPLOTLIB WE WORK IMAGE WITH OPENCV

# %%
import cv2

# %%
myimg = cv2.imread(r'/Users/venkat/Downloads/myimage.jpg')

# %%
wrong_img = cv2.imread(r'/Users/venkat/Downloads/dog.jpg')  # cv2.imread never gives ERROR even the file does not exist
# Out:
# [ WARN:0@0.522] global loadsave.cpp:275 findDecoder imread_('/Users/venkat/Downloads/dog.jpg'): can't open/read file: check file path/integrity

# %%
type(wrong_img)
# Out:
# NoneType

# %%
type(myimg)
# Out:
# numpy.ndarray

# %%
import cv2

img = cv2.imread('/Users/venkat/Downloads/myimage.jpg')

cv2.imshow('venky', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.waitKey(1)   # required on macOS
# Out:
# -1

# %%
import cv2

img = cv2.imread('/Users/venkat/Downloads/myimage.jpg')

while True:
    cv2.imshow('venky', img)
    if cv2.waitKey(10) == 27:  # ESC key
        break

cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# -1
