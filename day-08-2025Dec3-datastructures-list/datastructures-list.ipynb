# %%
l = []
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 0

# %%
l.append(10)
l
# Out:
# [10]

# %%
l.append(20)
l.append(30)
l.append(40)
l
# Out:
# [10, 20, 30, 40]

# %%
l1 = l.copy()
l1
# Out:
# [10, 20, 30, 40]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40]
# [10, 20, 30, 40]

# %%
l.append('hi', 1+2j, 2.3, True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 l.append('hi', 1+2j, 2.3, True)
#
# TypeError: list.append() takes exactly one argument (4 given)

# %%
l1
# Out:
# [10, 20, 30, 40]

# %%
l1.append(2.4)
l1.append(1+2j)
l1.append(True)
l1.append('venky')
l1
# Out:
# [10, 20, 30, 40, 2.4, (1+2j), True, 'venky']

# %%
print(len(l))
print(len(l1))
# Out:
# 4
# 8

# %%
l
# Out:
# [10, 20, 30, 40]

# %%
l.append(10)
l
# Out:
# [10, 20, 30, 40, 10]

# %%
l3=[1,2,3,4,5,66,7,8,'venky','singam',(1+2j),True]
l3
# Out:
# [1, 2, 3, 4, 5, 66, 7, 8, 'venky', 'singam', (1+2j), True]

# %%
l3.clear()
l3
# Out:
# []

# %%
del l3

# %%
l3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 l3
#
# NameError: name 'l3' is not defined

# %%
l
# Out:
# [10, 20, 30, 40, 10]

# %%
l.count(20)
# Out:
# 1

# %%
l.count(10)
# Out:
# 2

# %%
l1
# Out:
# [10, 20, 30, 40, 2.4, (1+2j), True, 'venky']

# %%
l
# Out:
# [10, 20, 30, 40, 10]

# %%
l[:]
# Out:
# [10, 20, 30, 40, 10]

# %%
l[2:]
# Out:
# [30, 40, 10]

# %%
l[:-1]
# Out:
# [10, 20, 30, 40]

# %%
l[:::-1] # only 2 slicing allowed but defined 3
# Out:
#   Cell In[32], line 1
#     l[:::-1] # only 2 slicing allowed but defined 3
#         ^
# SyntaxError: invalid syntax

# %%
l
# Out:
# [10, 20, 30, 40, 10]

# %%
l1
# Out:
# [10, 20, 30, 40, 2.4, (1+2j), True, 'venky']

# %%
l1.index('venky')
# Out:
# 7

# %%
l1[7]
# Out:
# 'venky'

# %%
l
# Out:
# [10, 20, 30, 40, 10]

# %%
l[::-1]
# Out:
# [10, 40, 30, 20, 10]

# %%
l
# Out:
# [10, 20, 30, 40, 10]

# %%
l[::1]
# Out:
# [10, 20, 30, 40, 10]

# %%
l[::2]
# Out:
# [10, 30, 10]

# %%
l
# Out:
# [10, 20, 30, 40, 10]

# %%
l[::3]
# Out:
# [10, 40]

# %%
l1
# Out:
# [10, 20, 30, 40, 2.4, (1+2j), True, 'venky']

# %%
l1[1:10:3]
# Out:
# [20, 2.4, 'venky']

# %%
l1[3:5:6]
# Out:
# [40]

# %%
l
# Out:
# [10, 20, 30, 40, 10]

# %%
l.append(10) # run the cell 3 times to append 10 three times
l
# Out:
# [10, 20, 30, 40, 10, 10, 10, 10]
