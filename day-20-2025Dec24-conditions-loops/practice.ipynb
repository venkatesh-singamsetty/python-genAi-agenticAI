# %%
# number is even or odd

x = 4
r = x % 2

if r == 0:
    print("Even")
# Out:
# Even

# %%
x = 5
r = x % 2

if r == 0:
    print("Even")

# %%
i = 1
while i <= 2:
    j = 0
    while j <= 2:
        print(i * j, end=" ")
        j += 1
    print()
    i += 1
# Out:
# 0 1 2
# 0 2 4

# %%
i = 1
while i <= 4:
    j = 0
    while j <= 3:
        print(i * j, end=" ")
        j += 1
    print()
    i += 1
# Out:
# 0 1 2 3
# 0 2 4 6
# 0 3 6 9
# 0 4 8 12
