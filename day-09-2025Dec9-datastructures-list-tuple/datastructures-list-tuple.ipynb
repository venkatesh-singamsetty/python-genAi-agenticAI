# %%
l = [10, 20, 30, 40, 10]
l1 = [10, 20, 30, 40]
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 10]
# [10, 20, 30, 40]

# %%
l[0]
# Out:
# 10

# %%
l[0] = 100
l
# Out:
# [100, 20, 30, 40, 10]

# %%
l[-1] = 1000
l
# Out:
# [100, 20, 30, 40, 1000]

# %%
l1
# Out:
# [10, 20, 30, 40]

# %%
l2 = []
l2
# Out:
# []

# %%
l2.extend(l1)
l2
# Out:
# [10, 20, 30, 40]

# %%
l2.extend(l)
l2
# Out:
# [10, 20, 30, 40, 100, 20, 30, 40, 1000]

# %%
l
# Out:
# [100, 20, 30, 40, 1000]

# %%
l.index(20)
# Out:
# 1

# %%
l.insert(2, 25)
l
# Out:
# [100, 20, 25, 30, 40, 1000]

# %%
l.insert(0,0)
l
# Out:
# [0, 100, 20, 25, 30, 40, 1000]

# %%
l1
# Out:
# [10, 20, 30, 40]

# %%
for i in l1:
    print(i)
# Out:
# 10
# 20
# 30
# 40

# %%
for i in enumerate(l1):
    print(i)
# Out:
# (0, 10)
# (1, 20)
# (2, 30)
# (3, 40)

# %%
l
# Out:
# [0, 100, 20, 25, 30, 40, 1000]

# %%
l.pop()
# Out:
# 1000

# %%
l
# Out:
# [0, 100, 20, 25, 30, 40]

# %%
l.pop(0)
# Out:
# 0

# %%
l
# Out:
# [100, 20, 25, 30, 40]

# %%
l.pop()
# Out:
# 40

# %%
l
# Out:
# [100, 20, 25, 30]

# %%
l.pop(2)
# Out:
# 25

# %%
l
# Out:
# [100, 20, 30]

# %%
l1
# Out:
# [10, 20, 30, 40]

# %%
l2
# Out:
# [10, 20, 30, 40, 100, 20, 30, 40, 1000]

# %%
del(l[0])

# %%
l
# Out:
# [20, 30]

# %%
l1
# Out:
# [10, 20, 30, 40]

# %%
l1.remove(1+2j)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 l1.remove(1+2j)
#
# ValueError: list.remove(x): x not in list

# %%
l1.reverse()

# %%
l1
# Out:
# [40, 30, 20, 10]

# %%
l1[::-1]
# Out:
# [10, 20, 30, 40]

# %%
l1
# Out:
# [40, 30, 20, 10]

# %%
l1.sort()

# %%
l1
# Out:
# [10, 20, 30, 40]

# %%
l3 = ['z', 'x', 'm']

# %%
l3.sort()

# %%
l3
# Out:
# ['m', 'x', 'z']

# %%
l2
# Out:
# [10, 20, 30, 40, 100, 20, 30, 40, 1000]

# %%
l2.sort()

# %%
l2
# Out:
# [10, 20, 20, 30, 30, 40, 40, 100, 1000]

# %%
l2.sort(reverse=True)

# %%
l2
# Out:
# [1000, 100, 40, 40, 30, 30, 20, 20, 10]

# %%
l
# Out:
# [20, 30]

# %%
200 in l
# Out:
# False

# %%
all(l)
# Out:
# True

# %%
any(l)
# Out:
# True

# %%
l.append(0)

# %%
l
# Out:
# [20, 30, 0]

# %%
all(l)
# Out:
# False

# %%
any(l)
# Out:
# True

# %% [markdown]
# ## TUPLE

# %%
t1 = (10, 20, 30)

# %%
t1
# Out:
# (10, 20, 30)

# %%
type(t1)
# Out:
# tuple

# %%
icici = (1234, 'cd455ff', 2000)
icici
# Out:
# (1234, 'cd455ff', 2000)

# %%
icici.remove(2000)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 icici.remove(2000)
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %%
icici
# Out:
# (1234, 'cd455ff', 2000)

# %%
icici[0] = 324324
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 icici[0] = 324324
#
# TypeError: 'tuple' object does not support item assignment

# %%
icici
# Out:
# (1234, 'cd455ff', 2000)

# %%
t1
# Out:
# (10, 20, 30)

# %%
t1.count(10)
# Out:
# 1

# %%
t2 = (20, 20)

# %%
t2[:]
# Out:
# (20, 20)

# %%
t2
# Out:
# (20, 20)

# %%
t1
# Out:
# (10, 20, 30)

# %%
t1.index(10)
# Out:
# 0

# %%
t2.count(20)
# Out:
# 2

# %%
t1
# Out:
# (10, 20, 30)

# %%
for i in t1:
    print(i)
# Out:
# 10
# 20
# 30

# %%
for i in enumerate(t1):
    print(i)
# Out:
# (0, 10)
# (1, 20)
# (2, 30)

# %%
t2
# Out:
# (20, 20)

# %%
t2 = ([1, 2, 3], 'hi', 3, (5+6j))
t2
# Out:
# ([1, 2, 3], 'hi', 3, (5+6j))
